# %%
# import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = np.array([(2, 1), (3, 4), (5, 0), (7, 6), (9, 2)])

# %%
mean = np.mean(data, axis=0)
std_dev = np.std(data, axis=0)
data_std = (data - mean) / std_dev

# %%
cov_matrix = np.cov(data_std, rowvar=False)

# %%
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

# %%
n_components = 2
idx = eigenvalues.argsort()[::-1]
eigenvectors = eigenvectors[:, idx]
eigenvectors = eigenvectors[:, :n_components]

# %%
data_transformed = np.dot(data_std, eigenvectors)

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(data[:, 0], data[:, 1])
plt.title('Original Data')
# Out:
# Text(0.5, 1.0, 'Original Data')

# %%
plt.subplot(1, 2, 2)
plt.scatter(data_transformed[:, 0], data_transformed[:, 1])
plt.title('Transformed Data')
# Out:
# Text(0.5, 1.0, 'Transformed Data')

# %%
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %%
mean = np.mean(X, axis=0)
std_dev = np.std(X, axis=0)
X_std = (X - mean) / std_dev

# %%
cov_matrix = np.cov(X_std, rowvar=False)

# %%
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

# %%
n_components = 2
idx = eigenvalues.argsort()[::-1]
eigenvectors = eigenvectors[:, idx]
eigenvectors = eigenvectors[:, :n_components]

# %%
X_transformed = np.dot(X_std, eigenvectors)

# %%
plt.figure(figsize=(8, 6))
colors = ['red', 'green', 'blue']
for i in range(len(colors)):
    plt.scatter(X_transformed[y == i, 0], X_transformed[y == i, 1], c=colors[i], label=iris.target_names[i])

plt.title('PCA of Iris Dataset')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Class')
plt.grid(True)
plt.show()
